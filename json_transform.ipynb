# %%
#### json -> QB ####

# %%
# modules and libraries:
import itertools, json, pandas as pd, numpy as np

# %%
# open and read .json:
def open_json():
    with open("PDM_json_to_test.json",
                  mode = "r",
                  encoding = "utf8") as f:
        data = json.loads(f.read())
    return data

open_json()
# Out:
# {'type': 'root',
#  'children': [{'identifier': 'enumerator_id',
#    'title': 'Enumerator ID',
#    'type': 'text',
#    'required_rule': 'always'},
#   {'identifier': 'consent_text',
#    'title': 'My name is [Enumerator name] and I work for the [International Committee of the Red Cross / Name of National Society]. [ICRC / NS on behalf of the ICRC] is collecting [type of data] from [type of respondents] in [Area/Country]. We would like to ask you some questions about your [type of data]. The purpose of collecting this information is to support [ICRC and/or NS]’s operational planning and decisions regarding its [type of intervention] to assist the most vulnerable population in the area. The survey usually takes [length in minutes] to complete. Any information that you provide will only be used by [ICRC and/or NS] and is not subject to further disclosure. Your participation is voluntary. We need your genuine responses and hope that you agree to participate.',
#    'type': 'text',
#    'readonly_rule': 'always'},
#   {'identifier': 'consent',
#    'title': 'Do you consent to being interviewed?',
#    'type': 'boolean',
#    'required_rule': 'always'},
#   {'identifier': 'date',
#    'title': 'Date',
#    'type': 'date',
#    'required_rule': 'always'},
#   {'identifier': 'name_of_the_form',
#    'title': 'Form name',
#    'options': [{'text': 'Form name', 'identifier': 'Form name'}],
#    'type': 'select',
#    'required_rule': 'always'},
#   {'identifier': 'round_nmb',
#    'title': 'Round number',
#    'options': [{'text': '1', 'identifier': '1'},
#     {'text': '2', 'identifier': '2'},
#     {'text': '3', 'identifier': '3'}],
#    'type': 'select',
#    'required_rule': 'always',
#    'validate_expr': 'NOTBLANK(round_nmb)'},
#   {'type': 'group',
#    'children': [{'identifier': 'h_o_hh_name',
#      'title': 'What is the name of the head of household',
#      'type': 'text',
#      'required_rule': 'always'},
#     {'identifier': 'UID',
#      'title': 'UID',
#      'type': 'text',
#      'required_rule': 'always'},
#     {'identifier': 'weeks_since_distribution',
#      'title': 'Number of weeks since the distribution',
#      'type': 'integer',
#      'required_rule': 'always'},
#     {'identifier': 'h_o_hh_phone',
#      'title': 'What is the phone number of the head of household',
#      'type': 'phone_number',
#      'required_rule': 'always'},
#     {'identifier': 'adm0',
#      'title': 'Country',
#      'options': [{'text': 'Burundi'},
#       {'text': 'CAR'},
#       {'text': 'DRC'},
#       {'text': 'Madagascar'},
#       {'text': 'Mozambique'},
#       {'text': 'Rwanda'},
#       {'text': 'Uganda'},
#       {'text': 'Eritrea'},
#       {'text': 'Ethiopia'},
#       {'text': 'Kenya'},
#       {'text': 'Somalia'},
#       {'text': 'South Sudan'},
#       {'text': 'Tanzania'},
#       {'text': 'Cameroon'},
#       {'text': 'Chad'},
#       {'text': 'Niger'},
#       {'text': 'Nigeria'},
#       {'text': 'Sudan'},
#       {'text': 'Algeria'},
#       {'text': 'Burkina Faso'},
#       {'text': 'Guinea-Bissau'},
#       {'text': 'Libya'},
#       {'text': 'Mali'},
#       {'text': 'Mauritania'},
#       {'text': 'Morocco'},
#       {'text': 'Senegal'},
#       {'text': 'Sierra Leone'},
#       {'text': 'Colombia'},
#       {'text': 'El Salvador'},
#       {'text': 'Guatemala'},
#       {'text': 'Haiti'},
#       {'text': 'Honduras'},
#       {'text': 'Mexico'},
#       {'text': 'Venezuela'},
#       {'text': 'Afghanistan'},
#       {'text': 'Bangladesh'},
#       {'text': "Democratic People's Republic of Korea"},
#       {'text': 'Myanmar'},
#       {'text': 'Pakistan'},
#       {'text': 'Papua New Guinea'},
#       {'text': 'Philippines'},
#       {'text': 'Sri Lanka'},
#       {'text': 'Armenia'},
#       {'text': 'Azerbaijan'},
#       {'text': 'Georgia'},
#       {'text': 'Greece'},
#       {'text': 'Ukraine'},
#       {'text': 'Djibouti'},
#       {'text': 'Egypt'},
#       {'text': 'ILOT'},
#       {'text': 'Iran'},
#       {'text': 'Iraq'},
#       {'text': 'Jordan'},
#       {'text': 'Lebanon'},
#       {'text': 'Syria'},
#       {'text': 'Yemen'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'adm1',
#      'title': 'Region',
#      'options': [{'text': 'Region 1'},
#       {'text': 'Region 2'},
#       {'text': 'Region 3'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'adm2',
#      'title': 'Sub Region',
#      'options': [{'text': 'Sub Region 1'},
#       {'text': 'Sub Region 2'},
#       {'text': 'Sub Region 3'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'address_street',
#      'title': 'Address - Street name',
#      'type': 'text',
#      'required_rule': 'always'},
#     {'identifier': 'address_number',
#      'title': 'Address - Number',
#      'type': 'text',
#      'required_rule': 'always'},
#     {'identifier': 'address_notes',
#      'title': 'Address - Notes on location',
#      'type': 'text',
#      'required_rule': 'always',
#      'multi_line': True}],
#    'identifier': 'respondant_identity',
#    'title': 'Identity of the respondant',
#    'minOccurs': 1,
#    'maxOccurs': 1},
#   {'type': 'group',
#    'children': [{'identifier': 'gender',
#      'title': 'Gender of respondent',
#      'options': [{'text': 'Male', 'identifier': 'Musko'},
#       {'text': 'Female', 'identifier': 'Zensko'},
#       {'text': 'Other', 'identifier': 'Drugo'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'customOptionIdentifiers': True},
#     {'identifier': 'h_o_hh',
#      'title': 'Are you the head of household?',
#      'type': 'boolean',
#      'required_rule': 'always'},
#     {'identifier': 'h_o_hh_gender',
#      'title': 'If no, what is the gender of the head of household?',
#      'options': [{'text': 'Male', 'identifier': 'Musko'},
#       {'text': 'Female', 'identifier': 'Zensko'},
#       {'text': 'Other', 'identifier': 'Drugo'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'h_o_hh = false'},
#     {'identifier': 'h_o_hh_age',
#      'title': 'How old is the head of household',
#      'type': 'integer',
#      'required_rule': 'always',
#      'validate_expr': 'h_o_hh_age > 0'},
#     {'identifier': 'h_o_hh_marital_status',
#      'title': 'What is the marital status of the head of household',
#      'options': [{'text': 'Married', 'identifier': 'Married'},
#       {'text': 'Separated', 'identifier': 'Separated'},
#       {'text': 'Divorced', 'identifier': 'Divorced'},
#       {'text': 'Widowed', 'identifier': 'Widowed'},
#       {'text': 'Single', 'identifier': 'Single'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'tribe',
#      'title': 'What is your tribe [please contextualize the answer options to fit the situation on the ground]',
#      'options': [{'text': 'Tribe 1'},
#       {'text': 'Tribe 2'},
#       {'text': 'Tribe 3'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'ethnic_cult_identity',
#      'title': 'Ethnic / Cultural Identity',
#      'options': [{'text': 'Minority', 'identifier': 'Minority'},
#       {'text': 'Majority', 'identifier': 'Majority'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'hint': 'DO NOT ask the beneficiary. Should be answered by enumerator'},
#     {'identifier': 'male_child',
#      'title': 'Male Members of the Household aged 0-17',
#      'type': 'integer',
#      'required_rule': 'always',
#      'validate_expr': 'male_child >= 0'},
#     {'identifier': 'male_adult',
#      'title': 'Male Members of the Household aged 18-64',
#      'type': 'integer',
#      'required_rule': 'always',
#      'validate_expr': 'male_adult >= 0'},
#     {'identifier': 'male_old',
#      'title': 'Male Members of the Household aged 65+',
#      'type': 'integer',
#      'required_rule': 'always',
#      'validate_expr': 'male_old >= 0'},
#     {'identifier': 'female_child',
#      'title': 'Female Members of the Household aged 0-17',
#      'type': 'integer',
#      'required_rule': 'always',
#      'validate_expr': 'female_child >= 0'},
#     {'identifier': 'female_adult',
#      'title': 'Female Members of the Household aged 18-64',
#      'type': 'integer',
#      'required_rule': 'always',
#      'validate_expr': 'female_adult >= 0'},
#     {'identifier': 'female_old',
#      'title': 'Female Members of the Household aged 65+',
#      'type': 'integer',
#      'required_rule': 'always',
#      'validate_expr': 'female_old >= 0'},
#     {'identifier': 'female_pregnant',
#      'title': 'How many women in this household are currently pregnant or lactating?',
#      'type': 'integer',
#      'required_rule': 'always',
#      'validate_expr': 'female_pregnant >= 0'},
#     {'identifier': 'disabled',
#      'title': 'How many people in this household have a chronic disability/illness?',
#      'type': 'integer',
#      'required_rule': 'always',
#      'hint': 'A disability/illness they have had for 3 months or more that affects their ability to work',
#      'validate_expr': 'disabled >= 0'},
#     {'identifier': 'residence_status',
#      'title': 'Displacement Status',
#      'options': [{'text': 'Host', 'identifier': 'Host'},
#       {'text': 'Resident', 'identifier': 'Resident'},
#       {'text': 'IDP', 'identifier': 'IDP'},
#       {'text': 'Refugee', 'identifier': 'Refugee'},
#       {'text': 'Returnee', 'identifier': 'Returnee'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'origin_adm0',
#      'title': 'Country of Origin',
#      'options': [{'text': 'Burundi'},
#       {'text': 'CAR'},
#       {'text': 'DRC'},
#       {'text': 'Madagascar'},
#       {'text': 'Mozambique'},
#       {'text': 'Rwanda'},
#       {'text': 'Uganda'},
#       {'text': 'Eritrea'},
#       {'text': 'Ethiopia'},
#       {'text': 'Kenya'},
#       {'text': 'Somalia'},
#       {'text': 'South Sudan'},
#       {'text': 'Tanzania'},
#       {'text': 'Cameroon'},
#       {'text': 'Chad'},
#       {'text': 'Niger'},
#       {'text': 'Nigeria'},
#       {'text': 'Sudan'},
#       {'text': 'Algeria'},
#       {'text': 'Burkina Faso'},
#       {'text': 'Guinea-Bissau'},
#       {'text': 'Libya'},
#       {'text': 'Mali'},
#       {'text': 'Mauritania'},
#       {'text': 'Morocco'},
#       {'text': 'Senegal'},
#       {'text': 'Sierra Leone'},
#       {'text': 'Colombia'},
#       {'text': 'El Salvador'},
#       {'text': 'Guatemala'},
#       {'text': 'Haiti'},
#       {'text': 'Honduras'},
#       {'text': 'Mexico'},
#       {'text': 'Venezuela'},
#       {'text': 'Afghanistan'},
#       {'text': 'Bangladesh'},
#       {'text': "Democratic People's Republic of Korea"},
#       {'text': 'Myanmar'},
#       {'text': 'Pakistan'},
#       {'text': 'Papua New Guinea'},
#       {'text': 'Philippines'},
#       {'text': 'Sri Lanka'},
#       {'text': 'Armenia'},
#       {'text': 'Azerbaijan'},
#       {'text': 'Georgia'},
#       {'text': 'Greece'},
#       {'text': 'Ukraine'},
#       {'text': 'Djibouti'},
#       {'text': 'Egypt'},
#       {'text': 'ILOT'},
#       {'text': 'Iran'},
#       {'text': 'Iraq'},
#       {'text': 'Jordan'},
#       {'text': 'Lebanon'},
#       {'text': 'Syria'},
#       {'text': 'Yemen'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'OR(OR(residence_status = "Refugee",residence_status = "IDP"),residence_status = "Returnee")'},
#     {'identifier': 'origin_adm1',
#      'title': 'Region of Origin',
#      'options': [{'text': 'Region 1'},
#       {'text': 'Region 2'},
#       {'text': 'Region 3'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'OR(OR(residence_status = "Refugee",residence_status = "IDP"),residence_status = "Returnee")'},
#     {'identifier': 'origin_adm2',
#      'title': 'Sub Region of Origin',
#      'options': [{'text': 'Sub Region 1'},
#       {'text': 'Sub Region 2'},
#       {'text': 'Sub Region 3'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'OR(OR(residence_status = "Refugee",residence_status = "IDP"),residence_status = "Returnee")'},
#     {'identifier': 'origin_adm3',
#      'title': 'Village of Origin',
#      'options': [{'text': 'Village 1'},
#       {'text': 'Village 2'},
#       {'text': 'Village 3'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'OR(OR(residence_status = "Refugee",residence_status = "IDP"),residence_status = "Returnee")'}],
#    'identifier': 'demographic_information',
#    'title': 'Demographic Information',
#    'minOccurs': 1,
#    'maxOccurs': 1},
#   {'type': 'group',
#    'children': [{'identifier': 'assist_check',
#      'title': 'Did the household receive the [type of assistance]?',
#      'type': 'boolean',
#      'required_rule': 'always'},
#     {'identifier': 'assistance_type',
#      'title': 'If the respondent has received assistance, could you please specify what type of assistance(s) respondend received?',
#      'options': [{'text': 'Agro(Seeds and Tools)',
#        'identifier': 'Agro(Seeds and Tools)'},
#       {'text': 'Food', 'identifier': 'Food'},
#       {'text': 'Cash', 'identifier': 'Cash'},
#       {'text': 'EHI', 'identifier': 'EHI'},
#       {'text': 'Vouchers', 'identifier': 'Vouchers'},
#       {'text': 'In-kind', 'identifier': 'In-kind'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'multiple': True,
#      'visible_rule': 'when',
#      'visible_expr': 'assist_check = true'},
#     {'identifier': 'why_not_assisted',
#      'title': 'If no, why?',
#      'options': [{'text': 'I was not informed',
#        'identifier': 'I was not informed'},
#       {'text': 'I had to work and could not go',
#        'identifier': 'I had to work and could not go'},
#       {'text': 'My name was not in the list',
#        'identifier': 'My name was not in the list'},
#       {'text': 'The distribution was not safe',
#        'identifier': 'The distribution was not safe'},
#       {'text': 'I could not afford the travel cost',
#        'identifier': 'I could not afford the travel cost'},
#       {'text': 'Other', 'identifier': 'Other'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'assist_check = false'},
#     {'identifier': 'why_not_assisted_other',
#      'title': 'If Other, specify',
#      'type': 'text',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'why_not_assisted = "Other"'},
#     {'identifier': 'resp_check',
#      'title': 'Is the respondent the person who was the main responsible to receive the [type of assistance] (at the distribution / encashment point)? ',
#      'type': 'boolean',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'assist_check = true'},
#     {'identifier': 'qty_check',
#      'title': 'How much [quantity/value of assistance] did your household receive over [the length of programme / last distribution]',
#      'type': 'integer',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'assist_check = true'},
#     {'identifier': 'freq_check',
#      'title': 'How [often/many times] did your household receive assistance over [the length of programme / last distribution]',
#      'type': 'integer',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'assist_check = true'},
#     {'identifier': 'assistance_duration',
#      'title': 'How many weeks did it take the household to consume [assistance type] received over [the length of programme / last distribution]?',
#      'type': 'integer',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'assist_check = true'}],
#    'identifier': 'assistance_verification',
#    'title': 'Assistance verification',
#    'minOccurs': 1,
#    'maxOccurs': 1},
#   {'type': 'group',
#    'children': [{'identifier': 'distribution_distance',
#      'title': 'How far is the [distribution / encashment] point? (in kilometers)',
#      'type': 'integer',
#      'required_rule': 'always'},
#     {'identifier': 'distribution_time',
#      'title': 'How long does it take you to get to the [distribution / encashment] point? (minutes)',
#      'type': 'integer',
#      'required_rule': 'always'},
#     {'identifier': 'transport_means',
#      'title': 'How do you usually get there?',
#      'options': [{'text': 'Walk', 'identifier': 'Walk'},
#       {'text': 'Own vehicle', 'identifier': 'Own vehicle'},
#       {'text': 'Shared or borrowed vehicle',
#        'identifier': 'Shared or borrowed vehicle'},
#       {'text': 'Public transport', 'identifier': 'Public transport'},
#       {'text': 'Other', 'identifier': 'Other'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'transport_cost',
#      'title': 'How much does it cost you to travel there (either in gas or in payment for transport)? (local currency)',
#      'type': 'integer',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'transport_means <> "Walk"'},
#     {'identifier': 'physical_access',
#      'title': 'Are you ever not able to go to the [distribution / encashment / market] because it is either too far or too expensive?',
#      'type': 'boolean',
#      'required_rule': 'always'}],
#    'identifier': 'access_to_distribution_point',
#    'title': 'Access to distribution point',
#    'visible_rule': 'when',
#    'visible_expr': '.assistance_verification.assist_check = true',
#    'minOccurs': 1,
#    'maxOccurs': 1},
#   {'type': 'group',
#    'children': [{'identifier': 'market_distance',
#      'title': 'How far is the market? (in kilometers)',
#      'type': 'integer',
#      'required_rule': 'always'},
#     {'identifier': 'market_time',
#      'title': 'How long does it take you to get to the market? (minutes)',
#      'type': 'integer',
#      'required_rule': 'always'},
#     {'identifier': 'market_transport',
#      'title': 'How do you usually get there?',
#      'options': [{'text': 'Walk', 'identifier': 'Walk'},
#       {'text': 'Own vehicle', 'identifier': 'Own vehicle'},
#       {'text': 'Shared or borrowed vehicle',
#        'identifier': 'Shared or borrowed vehicle'},
#       {'text': 'Public transport', 'identifier': 'Public transport'},
#       {'text': 'Other', 'identifier': 'Other'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'market_transport_cost',
#      'title': 'How much does it cost you to travel there (either in gas or in payment for transport)? (local currency)',
#      'type': 'integer',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'market_transport <> "Walk"'},
#     {'identifier': 'market_too_far_expensive',
#      'title': 'Are you ever not able to go to the market because it is either too far or too expensive?',
#      'type': 'boolean',
#      'required_rule': 'always'}],
#    'identifier': 'access_to_market',
#    'title': 'Access to market',
#    'visible_rule': 'when',
#    'visible_expr': '.assistance_verification.assist_check = true',
#    'minOccurs': 1,
#    'maxOccurs': 1},
#   {'type': 'group',
#    'children': [{'identifier': 'safe_home_site',
#      'title': 'Do you feel safe going from your home to the [distribution / encashment] point?',
#      'type': 'boolean',
#      'required_rule': 'always'},
#     {'identifier': 'safe_home_site_reason',
#      'title': 'If no, why?',
#      'type': 'text',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'safe_home_site = false'},
#     {'identifier': 'safe_site',
#      'title': 'Do you feel safe while you are at the [distribution / encashment] point?',
#      'type': 'boolean',
#      'required_rule': 'always'},
#     {'identifier': 'safe_site_reason',
#      'title': 'If no, why?',
#      'type': 'text',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'safe_site = false'},
#     {'identifier': 'safe_site_home',
#      'title': 'Do you feel safe going home from the [distribution / encashment] point?',
#      'type': 'boolean',
#      'required_rule': 'always'},
#     {'identifier': 'safe_site_home_reason',
#      'title': 'If no, why?',
#      'type': 'text',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'safe_site_home = false'}],
#    'identifier': 'programme_site_safety',
#    'title': 'Programme site safety',
#    'visible_rule': 'when',
#    'visible_expr': 'OR(.assistance_verification.assist_check = true,.assistance_verification.why_not_assisted = "The distribution was not safe")',
#    'minOccurs': 1,
#    'maxOccurs': 1},
#   {'type': 'group',
#    'children': [{'identifier': 'awareness_organisation',
#      'title': 'Do you know what organization provided the assistance?',
#      'options': [{'text': 'ICRC', 'identifier': 'ICRC'},
#       {'text': 'Red Cross/Red Crescent',
#        'identifier': 'Red Cross/Red Crescent'},
#       {'text': 'Government', 'identifier': 'Government'},
#       {'text': 'Other', 'identifier': 'Other'},
#       {'text': "Don't know", 'identifier': "Don't know"}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'icrc_service_aware',
#      'title': 'Do you feel you have been told about the ICRC services available to you?',
#      'type': 'boolean',
#      'required_rule': 'always'},
#     {'identifier': 'icrc_service_understand',
#      'title': 'Did you understand what you were told?',
#      'type': 'boolean',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'icrc_service_aware = true'}],
#    'identifier': 'communication',
#    'title': 'Communication',
#    'visible_rule': 'when',
#    'visible_expr': '.assistance_verification.assist_check = true',
#    'minOccurs': 1,
#    'maxOccurs': 1},
#   {'type': 'group',
#    'children': [{'identifier': 'assistance_quantity',
#      'title': 'The amount of [assistance type] received was sufficient',
#      'options': [{'text': 'Strongly Agree', 'identifier': 'Strongly Agree'},
#       {'text': 'Agree', 'identifier': 'Agree'},
#       {'text': 'Neutral', 'identifier': 'Neutral'},
#       {'text': 'Disagree', 'identifier': 'Disagree'},
#       {'text': 'Strongly Disagree', 'identifier': 'Strongly Disagree'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'low_quantity_item',
#      'title': 'If disagree or strongly disagree, which [assistance type items] do you think the amount given to you was not sufficient?',
#      'options': [{'text': 'Blanket', 'identifier': 'Blanket'},
#       {'text': 'Cooking pot', 'identifier': 'Cooking pot'},
#       {'text': 'Disposable sanitary pads',
#        'identifier': 'Disposable sanitary pads'},
#       {'text': 'Hoe', 'identifier': 'Hoe'},
#       {'text': 'Sickle', 'identifier': 'Sickle'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'OR(assistance_quantity = "Strongly Disagree",assistance_quantity = "Disagree")'},
#     {'identifier': 'assistance_frequency',
#      'title': 'The frequency of the [assistance type] was good',
#      'options': [{'text': 'Strongly Agree', 'identifier': 'Strongly Agree'},
#       {'text': 'Agree', 'identifier': 'Agree'},
#       {'text': 'Neutral', 'identifier': 'Neutral'},
#       {'text': 'Disagree', 'identifier': 'Disagree'},
#       {'text': 'Strongly Disagree', 'identifier': 'Strongly Disagree'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'assistance_quality',
#      'title': 'The quality of [assistance type / service provider] was good',
#      'options': [{'text': 'Strongly Agree', 'identifier': 'Strongly Agree'},
#       {'text': 'Agree', 'identifier': 'Agree'},
#       {'text': 'Neutral', 'identifier': 'Neutral'},
#       {'text': 'Disagree', 'identifier': 'Disagree'},
#       {'text': 'Strongly Disagree', 'identifier': 'Strongly Disagree'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'low_quality_item',
#      'title': 'If disagree or strongly disagree, please indicate the [assistance type items] that you received with poor quality',
#      'options': [{'text': 'Blanket', 'identifier': 'Blanket'},
#       {'text': 'Cooking pot', 'identifier': 'Cooking pot'},
#       {'text': 'Disposable sanitary pads',
#        'identifier': 'Disposable sanitary pads'},
#       {'text': 'Hoe', 'identifier': 'Hoe'},
#       {'text': 'Sickle', 'identifier': 'Sickle'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'OR(assistance_quality = "Strongly Disagree",assistance_quality = "Disagree")'},
#     {'identifier': 'assistance_delivery',
#      'title': 'The [delivery mechanism / transfer solution] functioned well',
#      'options': [{'text': 'Strongly Agree', 'identifier': 'Strongly Agree'},
#       {'text': 'Agree', 'identifier': 'Agree'},
#       {'text': 'Neutral', 'identifier': 'Neutral'},
#       {'text': 'Disagree', 'identifier': 'Disagree'},
#       {'text': 'Strongly Disagree', 'identifier': 'Strongly Disagree'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'assistance_behaviour',
#      'title': 'The behaviour of staff at the [distribution / encashment] point was good ',
#      'options': [{'text': 'Strongly Agree', 'identifier': 'Strongly Agree'},
#       {'text': 'Agree', 'identifier': 'Agree'},
#       {'text': 'Neutral', 'identifier': 'Neutral'},
#       {'text': 'Disagree', 'identifier': 'Disagree'},
#       {'text': 'Strongly Disagree', 'identifier': 'Strongly Disagree'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'appropriate_germination',
#      'title': 'The germination rate was good',
#      'options': [{'text': 'Strongly Agree', 'identifier': 'Strongly Agree'},
#       {'text': 'Agree', 'identifier': 'Agree'},
#       {'text': 'Neutral', 'identifier': 'Neutral'},
#       {'text': 'Disagree', 'identifier': 'Disagree'},
#       {'text': 'Strongly Disagree', 'identifier': 'Strongly Disagree'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'CONTAINS(.assistance_verification.assistance_type,"Agro(Seeds and Tools)")'},
#     {'identifier': 'low_germination',
#      'title': 'If disagree or strongly disagree, please indicate the [assistance type items] that were not useful for your household',
#      'options': [{'text': 'Maize', 'identifier': 'Maize'},
#       {'text': 'Sorghum', 'identifier': 'Sorghum'},
#       {'text': 'Wheat', 'identifier': 'Wheat'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'OR(appropriate_germination = "Strongly Disagree",appropriate_germination = "Disagree")'},
#     {'identifier': 'assistance_relevant',
#      'title': 'The [assistance type] received was [useful / helpful] for [myself/my household] / [my livelihood]',
#      'options': [{'text': 'Strongly Agree', 'identifier': 'Strongly Agree'},
#       {'text': 'Agree', 'identifier': 'Agree'},
#       {'text': 'Neutral', 'identifier': 'Neutral'},
#       {'text': 'Disagree', 'identifier': 'Disagree'},
#       {'text': 'Strongly Disagree', 'identifier': 'Strongly Disagree'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'Item_not_useful',
#      'title': 'If disagree or strongly disagree, please indicate the [assistance type items] that were not useful for your household',
#      'options': [{'text': 'Blanket', 'identifier': 'Blanket'},
#       {'text': 'Cooking pot', 'identifier': 'Cooking pot'},
#       {'text': 'Disposable sanitary pads',
#        'identifier': 'Disposable sanitary pads'},
#       {'text': 'Hoe', 'identifier': 'Hoe'},
#       {'text': 'Sickle', 'identifier': 'Sickle'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'OR(assistance_relevant = "Strongly Disagree",assistance_relevant = "Disagree")'},
#     {'identifier': 'basic_needs_perception',
#      'title': 'The support provided to you by the [assistance type] allows you to cover [basic needs/objective]',
#      'options': [{'text': 'Strongly Agree', 'identifier': 'Strongly Agree'},
#       {'text': 'Agree', 'identifier': 'Agree'},
#       {'text': 'Neutral', 'identifier': 'Neutral'},
#       {'text': 'Disagree', 'identifier': 'Disagree'},
#       {'text': 'Strongly Disagree', 'identifier': 'Strongly Disagree'}],
#      'type': 'select',
#      'required_rule': 'always'},
#     {'identifier': 'timely_response_perception',
#      'title': 'Did you receive the [assistance type] distributed in time to respond to your [basic needs/objective]?',
#      'options': [{'text': 'Early', 'identifier': 'Early'},
#       {'text': 'On time', 'identifier': 'On time'},
#       {'text': 'Late', 'identifier': 'Late'}],
#      'type': 'select',
#      'required_rule': 'always'}],
#    'identifier': 'perception_of_appropriateness_of_icrc_assistance',
#    'title': 'Perception of Appropriateness of ICRC Assistance',
#    'visible_rule': 'when',
#    'visible_expr': '.assistance_verification.assist_check = true',
#    'minOccurs': 1,
#    'maxOccurs': 1},
#   {'type': 'group',
#    'children': [{'identifier': 'targeting_awareness',
#      'title': 'What were the selection criteria for receiving this assistance? ',
#      'options': [{'text': 'Aware', 'identifier': 'Da'},
#       {'text': 'Not Aware', 'identifier': 'Ne'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'hint': 'Enumerators will ask this question and tick the box if the respondent answers correctly.'},
#     {'identifier': 'icrc_targeting_good',
#      'title': 'Do you think that the [services ICRC is providing] [is/are] reaching the [households/people] most in need?',
#      'type': 'boolean',
#      'required_rule': 'always'},
#     {'identifier': 'icrc_targeting_improvement',
#      'title': 'How can ICRC do better in reaching the households most in need?',
#      'type': 'text',
#      'required_rule': 'always',
#      'multi_line': True},
#     {'identifier': 'registration_problems',
#      'title': 'Did the household face any problems in registering for the programme?',
#      'type': 'boolean',
#      'required_rule': 'always'},
#     {'identifier': 'registration_bribe',
#      'title': 'In exchange for being included in the assistance, did you have to pay any fee, or give a favour in return? ',
#      'type': 'boolean',
#      'required_rule': 'always'}],
#    'identifier': 'perception_of_registration_process_and_targeting',
#    'title': 'Perception of registration process and targeting',
#    'visible_rule': 'when',
#    'visible_expr': '.assistance_verification.assist_check = true',
#    'minOccurs': 1,
#    'maxOccurs': 1},
#   {'type': 'group',
#    'children': [{'identifier': 'icrc_feedback',
#      'title': 'If you have any suggestions or complaints about ICRC services/projects, do you know how to contact ICRC?',
#      'type': 'boolean',
#      'required_rule': 'always'},
#     {'identifier': 'icrc_feedback_mechanism',
#      'title': 'If yes, how do you do this? (Do not read the options, listen and check all that apply)',
#      'options': [{'text': 'Speak to a volunteer',
#        'identifier': 'Speak to a volunteer'},
#       {'text': 'Write a letter', 'identifier': 'Write a letter'},
#       {'text': 'Go to the office', 'identifier': 'Go to the office'},
#       {'text': 'Call the hotline number',
#        'identifier': 'Call the hotline number'},
#       {'text': 'Call the office number',
#        'identifier': 'Call the office number'},
#       {'text': 'Other', 'identifier': 'Other'}],
#      'type': 'select',
#      'required_rule': 'always',
#      'multiple': True,
#      'visible_rule': 'when',
#      'visible_expr': 'icrc_feedback = true'},
#     {'identifier': 'icrc_feedback_mechanism_other',
#      'title': 'If Other, specify',
#      'type': 'text',
#      'required_rule': 'always',
#      'visible_rule': 'when',
#      'visible_expr': 'CONTAINS(icrc_feedback_mechanism,"Other")'}],
#    'identifier': 'feedback_mechanisms',
#    'title': 'Feedback mechanisms',
#    'minOccurs': 1,
#    'maxOccurs': 1},
#   {'identifier': 'additional_comment',
#    'title': 'Do you have any additional feedback for the ICRC?',
#    'type': 'text',
#    'multi_line': True}],
#  'title': 'PDM_json_to_test',
#  'description': 'form description'}

# %%
# normalisation of .json:
def normalize():
    df = pd.json_normalize(open_json()["children"])
    return df

normalize().head(5)
# Out:
#          identifier                                              title  \
# 0     enumerator_id                                      Enumerator ID
# 1      consent_text  My name is [Enumerator name] and I work for th...
# 2           consent               Do you consent to being interviewed?
# 3              date                                               Date
# 4  name_of_the_form                                          Form name
#
#       type required_rule readonly_rule  \
# 0     text        always           NaN
# 1     text           NaN        always
# 2  boolean        always           NaN
# 3     date        always           NaN
# 4   select        always           NaN
#
#                                              options validate_expr children  \
# 0                                                NaN           NaN      NaN
# 1                                                NaN           NaN      NaN
# 2                                                NaN           NaN      NaN
# 3                                                NaN           NaN      NaN
# 4  [{'text': 'Form name', 'identifier': 'Form nam...           NaN      NaN
#
#    minOccurs  maxOccurs visible_rule visible_expr multi_line
# 0        NaN        NaN          NaN          NaN        NaN
# 1        NaN        NaN          NaN          NaN        NaN
# 2        NaN        NaN          NaN          NaN        NaN
# 3        NaN        NaN          NaN          NaN        NaN
# 4        NaN        NaN          NaN          NaN        NaN

# %%
# remove sufficient cols:
cols_to_del = ["minOccurs",
               "maxOccurs",
               "children",
               "autoIdentifier",
               "customOptionIdentifiers"]

df = normalize()
for a in cols_to_del:
    try:
        df = df.drop(columns=[a])
    except Exception:
        pass
    
df.head(5)
# Out:
#          identifier                                              title  \
# 0     enumerator_id                                      Enumerator ID
# 1      consent_text  My name is [Enumerator name] and I work for th...
# 2           consent               Do you consent to being interviewed?
# 3              date                                               Date
# 4  name_of_the_form                                          Form name
#
#       type required_rule readonly_rule  \
# 0     text        always           NaN
# 1     text           NaN        always
# 2  boolean        always           NaN
# 3     date        always           NaN
# 4   select        always           NaN
#
#                                              options validate_expr  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4  [{'text': 'Form name', 'identifier': 'Form nam...           NaN
#
#   visible_rule visible_expr multi_line
# 0          NaN          NaN        NaN
# 1          NaN          NaN        NaN
# 2          NaN          NaN        NaN
# 3          NaN          NaN        NaN
# 4          NaN          NaN        NaN

# %%
# replace bools with Yes:
cols_to_replace = [
    "multi_line",
    "timestamp",
    "geostamp",
    "multiple"
]

for b in cols_to_replace:
    try:
        df[b].replace(True, "Yes",
                      regex = True,
                      inplace = True)
    except Exception:
        pass
    
df.head(5)
# Out:
#          identifier                                              title  \
# 0     enumerator_id                                      Enumerator ID
# 1      consent_text  My name is [Enumerator name] and I work for th...
# 2           consent               Do you consent to being interviewed?
# 3              date                                               Date
# 4  name_of_the_form                                          Form name
#
#       type required_rule readonly_rule  \
# 0     text        always           NaN
# 1     text           NaN        always
# 2  boolean        always           NaN
# 3     date        always           NaN
# 4   select        always           NaN
#
#                                              options validate_expr  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4  [{'text': 'Form name', 'identifier': 'Form nam...           NaN
#
#   visible_rule visible_expr multi_line
# 0          NaN          NaN        NaN
# 1          NaN          NaN        NaN
# 2          NaN          NaN        NaN
# 3          NaN          NaN        NaN
# 4          NaN          NaN        NaN

# %%
# extract list of title subforms:
def get_sforms():
    groups = (df[df["type"] == "group"])["title"].to_list()
    return groups

get_sforms()
# Out:
# ['Identity of the respondant',
#  'Demographic Information',
#  'Assistance verification',
#  'Access to distribution point',
#  'Access to market',
#  'Programme site safety',
#  'Communication',
#  'Perception of Appropriateness of ICRC Assistance',
#  'Perception of registration process and targeting',
#  'Feedback mechanisms']

# %%
# split dataframe - each row as separate df:
def split_dataframe(df, num_splits):
    num_rows = len(df)
    rows_per_split = int(np.ceil(num_rows / num_splits))
    splits = np.array_split(df, num_splits)
    split_dataframes = []
    for split in splits:
        split_dataframes.append(split)
    return split_dataframes

split_dataframes = split_dataframe(df, len(df))
split_dataframes[1]
# Out:
#      identifier                                              title  type  \
# 1  consent_text  My name is [Enumerator name] and I work for th...  text
#
#   required_rule readonly_rule options validate_expr visible_rule visible_expr  \
# 1           NaN        always     NaN           NaN          NaN          NaN
#
#   multi_line
# 1        NaN

# %%
# assign original df as main:
main_df = split_dataframes

# get list of single questions and subforms:
stru = []
acum = 0
for x in split_dataframes:
    if split_dataframes[acum]["type"].isin(["group"]).any():
        stru.append("subform")
        acum = acum + 1
    else:
        stru.append("single_question")
        acum = acum + 1
        
stru
# Out:
# ['single_question',
#  'single_question',
#  'single_question',
#  'single_question',
#  'single_question',
#  'single_question',
#  'subform',
#  'subform',
#  'subform',
#  'subform',
#  'subform',
#  'subform',
#  'subform',
#  'subform',
#  'subform',
#  'subform',
#  'single_question']

# %%
# fetch nested data:
def dataframes():
    nested = open_json()["children"]
    result = []
    for x in range(len(nested)):
        try:
            df = pd.json_normalize(nested[x],
                 record_path = ["children"])
            result.append(df)
        except: pass
    return result

dataframes()[0].head(5)
# Out:
#                  identifier  \
# 0               h_o_hh_name
# 1                       UID
# 2  weeks_since_distribution
# 3              h_o_hh_phone
# 4                      adm0
#
#                                                title          type  \
# 0          What is the name of the head of household          text
# 1                                                UID          text
# 2             Number of weeks since the distribution       integer
# 3  What is the phone number of the head of household  phone_number
# 4                                            Country        select
#
#   required_rule                                            options multi_line
# 0        always                                                NaN        NaN
# 1        always                                                NaN        NaN
# 2        always                                                NaN        NaN
# 3        always                                                NaN        NaN
# 4        always  [{'text': 'Burundi'}, {'text': 'CAR'}, {'text'...        NaN

# %%
# check subformed stru:
dataframes()
# Out:
# [                 identifier  \
#  0               h_o_hh_name
#  1                       UID
#  2  weeks_since_distribution
#  3              h_o_hh_phone
#  4                      adm0
#  5                      adm1
#  6                      adm2
#  7            address_street
#  8            address_number
#  9             address_notes
#
#                                                 title          type  \
#  0          What is the name of the head of household          text
#  1                                                UID          text
#  2             Number of weeks since the distribution       integer
#  3  What is the phone number of the head of household  phone_number
#  4                                            Country        select
#  5                                             Region        select
#  6                                         Sub Region        select
#  7                              Address - Street name          text
#  8                                   Address - Number          text
#  9                        Address - Notes on location          text
#
#    required_rule                                            options multi_line
#  0        always                                                NaN        NaN
#  1        always                                                NaN        NaN
#  2        always                                                NaN        NaN
#  3        always                                                NaN        NaN
#  4        always  [{'text': 'Burundi'}, {'text': 'CAR'}, {'text'...        NaN
#  5        always  [{'text': 'Region 1'}, {'text': 'Region 2'}, {...        NaN
#  6        always  [{'text': 'Sub Region 1'}, {'text': 'Sub Regio...        NaN
#  7        always                                                NaN        NaN
#  8        always                                                NaN        NaN
#  9        always                                                NaN       True  ,
#                 identifier                                              title  \
#  0                  gender                               Gender of respondent
#  1                  h_o_hh                     Are you the head of household?
#  2           h_o_hh_gender  If no, what is the gender of the head of house...
#  3              h_o_hh_age                   How old is the head of household
#  4   h_o_hh_marital_status  What is the marital status of the head of hous...
#  5                   tribe  What is your tribe [please contextualize the a...
#  6    ethnic_cult_identity                         Ethnic / Cultural Identity
#  7              male_child            Male Members of the Household aged 0-17
#  8              male_adult           Male Members of the Household aged 18-64
#  9                male_old             Male Members of the Household aged 65+
#  10           female_child          Female Members of the Household aged 0-17
#  11           female_adult         Female Members of the Household aged 18-64
#  12             female_old           Female Members of the Household aged 65+
#  13        female_pregnant  How many women in this household are currently...
#  14               disabled  How many people in this household have a chron...
#  15       residence_status                                Displacement Status
#  16            origin_adm0                                  Country of Origin
#  17            origin_adm1                                   Region of Origin
#  18            origin_adm2                               Sub Region of Origin
#  19            origin_adm3                                  Village of Origin
#
#                                                options     type required_rule  \
#  0   [{'text': 'Male', 'identifier': 'Musko'}, {'te...   select        always
#  1                                                 NaN  boolean        always
#  2   [{'text': 'Male', 'identifier': 'Musko'}, {'te...   select        always
#  3                                                 NaN  integer        always
#  4   [{'text': 'Married', 'identifier': 'Married'},...   select        always
#  5   [{'text': 'Tribe 1'}, {'text': 'Tribe 2'}, {'t...   select        always
#  6   [{'text': 'Minority', 'identifier': 'Minority'...   select        always
#  7                                                 NaN  integer        always
#  8                                                 NaN  integer        always
#  9                                                 NaN  integer        always
#  10                                                NaN  integer        always
#  11                                                NaN  integer        always
#  12                                                NaN  integer        always
#  13                                                NaN  integer        always
#  14                                                NaN  integer        always
#  15  [{'text': 'Host', 'identifier': 'Host'}, {'tex...   select        always
#  16  [{'text': 'Burundi'}, {'text': 'CAR'}, {'text'...   select        always
#  17  [{'text': 'Region 1'}, {'text': 'Region 2'}, {...   select        always
#  18  [{'text': 'Sub Region 1'}, {'text': 'Sub Regio...   select        always
#  19  [{'text': 'Village 1'}, {'text': 'Village 2'},...   select        always
#
#     customOptionIdentifiers visible_rule  \
#  0                     True          NaN
#  1                      NaN          NaN
#  2                      NaN         when
#  3                      NaN          NaN
#  4                      NaN          NaN
#  5                      NaN          NaN
#  6                      NaN          NaN
#  7                      NaN          NaN
#  8                      NaN          NaN
#  9                      NaN          NaN
#  10                     NaN          NaN
#  11                     NaN          NaN
#  12                     NaN          NaN
#  13                     NaN          NaN
#  14                     NaN          NaN
#  15                     NaN          NaN
#  16                     NaN         when
#  17                     NaN         when
#  18                     NaN         when
#  19                     NaN         when
#
#                                           visible_expr         validate_expr  \
#  0                                                 NaN                   NaN
#  1                                                 NaN                   NaN
#  2                                      h_o_hh = false                   NaN
#  3                                                 NaN        h_o_hh_age > 0
#  4                                                 NaN                   NaN
#  5                                                 NaN                   NaN
#  6                                                 NaN                   NaN
#  7                                                 NaN       male_child >= 0
#  8                                                 NaN       male_adult >= 0
#  9                                                 NaN         male_old >= 0
#  10                                                NaN     female_child >= 0
#  11                                                NaN     female_adult >= 0
#  12                                                NaN       female_old >= 0
#  13                                                NaN  female_pregnant >= 0
#  14                                                NaN         disabled >= 0
#  15                                                NaN                   NaN
#  16  OR(OR(residence_status = "Refugee",residence_s...                   NaN
#  17  OR(OR(residence_status = "Refugee",residence_s...                   NaN
#  18  OR(OR(residence_status = "Refugee",residence_s...                   NaN
#  19  OR(OR(residence_status = "Refugee",residence_s...                   NaN
#
#                                                   hint
#  0                                                 NaN
#  1                                                 NaN
#  2                                                 NaN
#  3                                                 NaN
#  4                                                 NaN
#  5                                                 NaN
#  6   DO NOT ask the beneficiary. Should be answered...
#  7                                                 NaN
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11                                                NaN
#  12                                                NaN
#  13                                                NaN
#  14  A disability/illness they have had for 3 month...
#  15                                                NaN
#  16                                                NaN
#  17                                                NaN
#  18                                                NaN
#  19                                                NaN  ,
#                 identifier                                              title  \
#  0            assist_check  Did the household receive the [type of assista...
#  1         assistance_type  If the respondent has received assistance, cou...
#  2        why_not_assisted                                        If no, why?
#  3  why_not_assisted_other                                  If Other, specify
#  4              resp_check  Is the respondent the person who was the main ...
#  5               qty_check  How much [quantity/value of assistance] did yo...
#  6              freq_check  How [often/many times] did your household rece...
#  7     assistance_duration  How many weeks did it take the household to co...
#
#        type required_rule                                            options  \
#  0  boolean        always                                                NaN
#  1   select        always  [{'text': 'Agro(Seeds and Tools)', 'identifier...
#  2   select        always  [{'text': 'I was not informed', 'identifier': ...
#  3     text        always                                                NaN
#  4  boolean        always                                                NaN
#  5  integer        always                                                NaN
#  6  integer        always                                                NaN
#  7  integer        always                                                NaN
#
#    multiple visible_rule                visible_expr
#  0      NaN          NaN                         NaN
#  1     True         when         assist_check = true
#  2      NaN         when        assist_check = false
#  3      NaN         when  why_not_assisted = "Other"
#  4      NaN         when         assist_check = true
#  5      NaN         when         assist_check = true
#  6      NaN         when         assist_check = true
#  7      NaN         when         assist_check = true  ,
#                identifier                                              title  \
#  0  distribution_distance  How far is the [distribution / encashment] poi...
#  1      distribution_time  How long does it take you to get to the [distr...
#  2        transport_means                      How do you usually get there?
#  3         transport_cost  How much does it cost you to travel there (eit...
#  4        physical_access  Are you ever not able to go to the [distributi...
#
#        type required_rule                                            options  \
#  0  integer        always                                                NaN
#  1  integer        always                                                NaN
#  2   select        always  [{'text': 'Walk', 'identifier': 'Walk'}, {'tex...
#  3  integer        always                                                NaN
#  4  boolean        always                                                NaN
#
#    visible_rule               visible_expr
#  0          NaN                        NaN
#  1          NaN                        NaN
#  2          NaN                        NaN
#  3         when  transport_means <> "Walk"
#  4          NaN                        NaN  ,
#                   identifier  \
#  0           market_distance
#  1               market_time
#  2          market_transport
#  3     market_transport_cost
#  4  market_too_far_expensive
#
#                                                 title     type required_rule  \
#  0             How far is the market? (in kilometers)  integer        always
#  1  How long does it take you to get to the market...  integer        always
#  2                      How do you usually get there?   select        always
#  3  How much does it cost you to travel there (eit...  integer        always
#  4  Are you ever not able to go to the market beca...  boolean        always
#
#                                               options visible_rule  \
#  0                                                NaN          NaN
#  1                                                NaN          NaN
#  2  [{'text': 'Walk', 'identifier': 'Walk'}, {'tex...          NaN
#  3                                                NaN         when
#  4                                                NaN          NaN
#
#                   visible_expr
#  0                         NaN
#  1                         NaN
#  2                         NaN
#  3  market_transport <> "Walk"
#  4                         NaN  ,
#                identifier                                              title  \
#  0         safe_home_site  Do you feel safe going from your home to the [...
#  1  safe_home_site_reason                                        If no, why?
#  2              safe_site  Do you feel safe while you are at the [distrib...
#  3       safe_site_reason                                        If no, why?
#  4         safe_site_home  Do you feel safe going home from the [distribu...
#  5  safe_site_home_reason                                        If no, why?
#
#        type required_rule visible_rule            visible_expr
#  0  boolean        always          NaN                     NaN
#  1     text        always         when  safe_home_site = false
#  2  boolean        always          NaN                     NaN
#  3     text        always         when       safe_site = false
#  4  boolean        always          NaN                     NaN
#  5     text        always         when  safe_site_home = false  ,
#                  identifier                                              title  \
#  0   awareness_organisation  Do you know what organization provided the ass...
#  1       icrc_service_aware  Do you feel you have been told about the ICRC ...
#  2  icrc_service_understand             Did you understand what you were told?
#
#                                               options     type required_rule  \
#  0  [{'text': 'ICRC', 'identifier': 'ICRC'}, {'tex...   select        always
#  1                                                NaN  boolean        always
#  2                                                NaN  boolean        always
#
#    visible_rule               visible_expr
#  0          NaN                        NaN
#  1          NaN                        NaN
#  2         when  icrc_service_aware = true  ,
#                      identifier  \
#  0          assistance_quantity
#  1            low_quantity_item
#  2         assistance_frequency
#  3           assistance_quality
#  4             low_quality_item
#  5          assistance_delivery
#  6         assistance_behaviour
#  7      appropriate_germination
#  8              low_germination
#  9          assistance_relevant
#  10             Item_not_useful
#  11      basic_needs_perception
#  12  timely_response_perception
#
#                                                  title  \
#  0   The amount of [assistance type] received was s...
#  1   If disagree or strongly disagree, which [assis...
#  2     The frequency of the [assistance type] was good
#  3   The quality of [assistance type / service prov...
#  4   If disagree or strongly disagree, please indic...
#  5   The [delivery mechanism / transfer solution] f...
#  6   The behaviour of staff at the [distribution / ...
#  7                       The germination rate was good
#  8   If disagree or strongly disagree, please indic...
#  9   The [assistance type] received was [useful / h...
#  10  If disagree or strongly disagree, please indic...
#  11  The support provided to you by the [assistance...
#  12  Did you receive the [assistance type] distribu...
#
#                                                options    type required_rule  \
#  0   [{'text': 'Strongly Agree', 'identifier': 'Str...  select        always
#  1   [{'text': 'Blanket', 'identifier': 'Blanket'},...  select        always
#  2   [{'text': 'Strongly Agree', 'identifier': 'Str...  select        always
#  3   [{'text': 'Strongly Agree', 'identifier': 'Str...  select        always
#  4   [{'text': 'Blanket', 'identifier': 'Blanket'},...  select        always
#  5   [{'text': 'Strongly Agree', 'identifier': 'Str...  select        always
#  6   [{'text': 'Strongly Agree', 'identifier': 'Str...  select        always
#  7   [{'text': 'Strongly Agree', 'identifier': 'Str...  select        always
#  8   [{'text': 'Maize', 'identifier': 'Maize'}, {'t...  select        always
#  9   [{'text': 'Strongly Agree', 'identifier': 'Str...  select        always
#  10  [{'text': 'Blanket', 'identifier': 'Blanket'},...  select        always
#  11  [{'text': 'Strongly Agree', 'identifier': 'Str...  select        always
#  12  [{'text': 'Early', 'identifier': 'Early'}, {'t...  select        always
#
#     visible_rule                                       visible_expr
#  0           NaN                                                NaN
#  1          when  OR(assistance_quantity = "Strongly Disagree",a...
#  2           NaN                                                NaN
#  3           NaN                                                NaN
#  4          when  OR(assistance_quality = "Strongly Disagree",as...
#  5           NaN                                                NaN
#  6           NaN                                                NaN
#  7          when  CONTAINS(.assistance_verification.assistance_t...
#  8          when  OR(appropriate_germination = "Strongly Disagre...
#  9           NaN                                                NaN
#  10         when  OR(assistance_relevant = "Strongly Disagree",a...
#  11          NaN                                                NaN
#  12          NaN                                                NaN  ,
#                     identifier  \
#  0         targeting_awareness
#  1         icrc_targeting_good
#  2  icrc_targeting_improvement
#  3       registration_problems
#  4          registration_bribe
#
#                                                 title  \
#  0  What were the selection criteria for receiving...
#  1  Do you think that the [services ICRC is provid...
#  2  How can ICRC do better in reaching the househo...
#  3  Did the household face any problems in registe...
#  4  In exchange for being included in the assistan...
#
#                                               options     type required_rule  \
#  0  [{'text': 'Aware', 'identifier': 'Da'}, {'text...   select        always
#  1                                                NaN  boolean        always
#  2                                                NaN     text        always
#  3                                                NaN  boolean        always
#  4                                                NaN  boolean        always
#
#                                                  hint multi_line
#  0  Enumerators will ask this question and tick th...        NaN
#  1                                                NaN        NaN
#  2                                                NaN       True
#  3                                                NaN        NaN
#  4                                                NaN        NaN  ,
#                        identifier  \
#  0                  icrc_feedback
#  1        icrc_feedback_mechanism
#  2  icrc_feedback_mechanism_other
#
#                                                 title     type required_rule  \
#  0  If you have any suggestions or complaints abou...  boolean        always
#  1  If yes, how do you do this? (Do not read the o...   select        always
#  2                                  If Other, specify     text        always
#
#                                               options multiple visible_rule  \
#  0                                                NaN      NaN          NaN
#  1  [{'text': 'Speak to a volunteer', 'identifier'...     True         when
#  2                                                NaN      NaN         when
#
#                                  visible_expr
#  0                                        NaN
#  1                       icrc_feedback = true
#  2  CONTAINS(icrc_feedback_mechanism,"Other")  ]

# %%
# assign subform title to each subformed question:
sub_df = dataframes()
acum = 0
for x, y in zip(sub_df, get_sforms()):
    sub_df[acum]["Parent Sub Form"] = y
    acum = acum + 1
    
sub_df[1].head(5)
# Out:
#               identifier                                              title  \
# 0                 gender                               Gender of respondent
# 1                 h_o_hh                     Are you the head of household?
# 2          h_o_hh_gender  If no, what is the gender of the head of house...
# 3             h_o_hh_age                   How old is the head of household
# 4  h_o_hh_marital_status  What is the marital status of the head of hous...
#
#                                              options     type required_rule  \
# 0  [{'text': 'Male', 'identifier': 'Musko'}, {'te...   select        always
# 1                                                NaN  boolean        always
# 2  [{'text': 'Male', 'identifier': 'Musko'}, {'te...   select        always
# 3                                                NaN  integer        always
# 4  [{'text': 'Married', 'identifier': 'Married'},...   select        always
#
#   customOptionIdentifiers visible_rule    visible_expr   validate_expr hint  \
# 0                    True          NaN             NaN             NaN  NaN
# 1                     NaN          NaN             NaN             NaN  NaN
# 2                     NaN         when  h_o_hh = false             NaN  NaN
# 3                     NaN          NaN             NaN  h_o_hh_age > 0  NaN
# 4                     NaN          NaN             NaN             NaN  NaN
#
#            Parent Sub Form
# 0  Demographic Information
# 1  Demographic Information
# 2  Demographic Information
# 3  Demographic Information
# 4  Demographic Information

# %%
# compare, align and merge main splitted df and
# subformed dfs into one:
def merge_dfs():
    final = []
    acum = 0
    for a, b, c in itertools.zip_longest(stru, main_df, sub_df):
        if a == "single_question":
            final.append(b)
        elif a == "subform":
            final.extend([b,sub_df[acum]])
            acum = acum + 1
    result = pd.concat(final)
    return result

final_df = merge_dfs()
final_df.head(5)
# Out:
#          identifier                                              title  \
# 0     enumerator_id                                      Enumerator ID
# 1      consent_text  My name is [Enumerator name] and I work for th...
# 2           consent               Do you consent to being interviewed?
# 3              date                                               Date
# 4  name_of_the_form                                          Form name
#
#       type required_rule readonly_rule  \
# 0     text        always           NaN
# 1     text           NaN        always
# 2  boolean        always           NaN
# 3     date        always           NaN
# 4   select        always           NaN
#
#                                              options validate_expr  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4  [{'text': 'Form name', 'identifier': 'Form nam...           NaN
#
#   visible_rule visible_expr multi_line Parent Sub Form  \
# 0          NaN          NaN        NaN             NaN
# 1          NaN          NaN        NaN             NaN
# 2          NaN          NaN        NaN             NaN
# 3          NaN          NaN        NaN             NaN
# 4          NaN          NaN        NaN             NaN
#
#   customOptionIdentifiers hint multiple
# 0                     NaN  NaN      NaN
# 1                     NaN  NaN      NaN
# 2                     NaN  NaN      NaN
# 3                     NaN  NaN      NaN
# 4                     NaN  NaN      NaN

# %%
# transform options:text part:
final_df["Options"] = (final_df["options"]
                    .apply(lambda x: ', '
                    .join([item["text"] for item in x]) if isinstance(x, list) else np.nan))

final_df.head(5)
# Out:
#          identifier                                              title  \
# 0     enumerator_id                                      Enumerator ID
# 1      consent_text  My name is [Enumerator name] and I work for th...
# 2           consent               Do you consent to being interviewed?
# 3              date                                               Date
# 4  name_of_the_form                                          Form name
#
#       type required_rule readonly_rule  \
# 0     text        always           NaN
# 1     text           NaN        always
# 2  boolean        always           NaN
# 3     date        always           NaN
# 4   select        always           NaN
#
#                                              options validate_expr  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4  [{'text': 'Form name', 'identifier': 'Form nam...           NaN
#
#   visible_rule visible_expr multi_line Parent Sub Form  \
# 0          NaN          NaN        NaN             NaN
# 1          NaN          NaN        NaN             NaN
# 2          NaN          NaN        NaN             NaN
# 3          NaN          NaN        NaN             NaN
# 4          NaN          NaN        NaN             NaN
#
#   customOptionIdentifiers hint multiple    Options
# 0                     NaN  NaN      NaN        NaN
# 1                     NaN  NaN      NaN        NaN
# 2                     NaN  NaN      NaN        NaN
# 3                     NaN  NaN      NaN        NaN
# 4                     NaN  NaN      NaN  Form name

# %%
# transform options:identifiers part:
def process_row(row):
    if isinstance(row, list):
        identifiers = [item.get("identifier") for item in row]
        identifier_result = ', '.join(filter(None, identifiers))
        return identifier_result if identifier_result else np.nan
    else:
        return np.nan
    
final_df["Option Identifiers"] = final_df["options"].apply(process_row)
final_df.head(5)
# Out:
#          identifier                                              title  \
# 0     enumerator_id                                      Enumerator ID
# 1      consent_text  My name is [Enumerator name] and I work for th...
# 2           consent               Do you consent to being interviewed?
# 3              date                                               Date
# 4  name_of_the_form                                          Form name
#
#       type required_rule readonly_rule  \
# 0     text        always           NaN
# 1     text           NaN        always
# 2  boolean        always           NaN
# 3     date        always           NaN
# 4   select        always           NaN
#
#                                              options validate_expr  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4  [{'text': 'Form name', 'identifier': 'Form nam...           NaN
#
#   visible_rule visible_expr multi_line Parent Sub Form  \
# 0          NaN          NaN        NaN             NaN
# 1          NaN          NaN        NaN             NaN
# 2          NaN          NaN        NaN             NaN
# 3          NaN          NaN        NaN             NaN
# 4          NaN          NaN        NaN             NaN
#
#   customOptionIdentifiers hint multiple    Options Option Identifiers
# 0                     NaN  NaN      NaN        NaN                NaN
# 1                     NaN  NaN      NaN        NaN                NaN
# 2                     NaN  NaN      NaN        NaN                NaN
# 3                     NaN  NaN      NaN        NaN                NaN
# 4                     NaN  NaN      NaN  Form name          Form name

# %%
# delete sufficient cols from merged df:
cols_to_del_two = ["minOccurs",
                   "maxOccurs",
                   "children",
                   "autoIdentifier",
                   "customOptionIdentifiers",
                   "options",
                   "visible_rule"]

for a in cols_to_del_two:
    try:
        final_df = final_df.drop(columns=[a])
    except Exception:
        pass
    
final_df.head(5)
# Out:
#          identifier                                              title  \
# 0     enumerator_id                                      Enumerator ID
# 1      consent_text  My name is [Enumerator name] and I work for th...
# 2           consent               Do you consent to being interviewed?
# 3              date                                               Date
# 4  name_of_the_form                                          Form name
#
#       type required_rule readonly_rule validate_expr visible_expr multi_line  \
# 0     text        always           NaN           NaN          NaN        NaN
# 1     text           NaN        always           NaN          NaN        NaN
# 2  boolean        always           NaN           NaN          NaN        NaN
# 3     date        always           NaN           NaN          NaN        NaN
# 4   select        always           NaN           NaN          NaN        NaN
#
#   Parent Sub Form hint multiple    Options Option Identifiers
# 0             NaN  NaN      NaN        NaN                NaN
# 1             NaN  NaN      NaN        NaN                NaN
# 2             NaN  NaN      NaN        NaN                NaN
# 3             NaN  NaN      NaN        NaN                NaN
# 4             NaN  NaN      NaN  Form name          Form name

# %%
# rename and relocate columns:
js = list(final_df.columns)
json_columns = js

final_columns = []
for x in json_columns:
    if x == "identifier":
        final_columns.append("Identifier")
    elif x == "title":
        final_columns.append("Question title")
    elif x == "required_rule":
        final_columns.append("Required")
    elif x == "timestamp":
        final_columns.append("Timestamp")
    elif x == "initialAnswer":
        final_columns.append("Initial value")
    elif x == "type":
        final_columns.append("Type")
    elif x == "validate_expr":
        final_columns.append("Validity expression")
    elif x == "calculate_expr":
        final_columns.append("Calculated expression")
    elif x == "type_derived":
        final_columns.append("Derived type")
    elif x == "geostamp":
        final_columns.append("Geostamp")
    elif x == "readonly_rule":
        final_columns.append("Read Only")
    elif x == "multi_line":
        final_columns.append("Long Text")
    elif x == "Parent Sub Form":
        final_columns.append("Parent Sub Form")
    elif x == "multiple":
        final_columns.append("Multi Choice")
    elif x == "hint":
        final_columns.append("Hint")
    elif x == "visible_expr":
        final_columns.append("Visibility expression")
    elif x == "Options":
        final_columns.append("Options")
    elif x == "Option Identifiers":
        final_columns.append("Option Identifiers")
        
final_df.columns = final_columns
final_df.head(5)
# Out:
#          Identifier                                     Question title  \
# 0     enumerator_id                                      Enumerator ID
# 1      consent_text  My name is [Enumerator name] and I work for th...
# 2           consent               Do you consent to being interviewed?
# 3              date                                               Date
# 4  name_of_the_form                                          Form name
#
#       Type Required Read Only Validity expression Visibility expression  \
# 0     text   always       NaN                 NaN                   NaN
# 1     text      NaN    always                 NaN                   NaN
# 2  boolean   always       NaN                 NaN                   NaN
# 3     date   always       NaN                 NaN                   NaN
# 4   select   always       NaN                 NaN                   NaN
#
#   Long Text Parent Sub Form Hint Multi Choice    Options Option Identifiers
# 0       NaN             NaN  NaN          NaN        NaN                NaN
# 1       NaN             NaN  NaN          NaN        NaN                NaN
# 2       NaN             NaN  NaN          NaN        NaN                NaN
# 3       NaN             NaN  NaN          NaN        NaN                NaN
# 4       NaN             NaN  NaN          NaN  Form name          Form name

# %%
# relocate and and add missing columns:
origin = ['Question title', 'Identifier', 'Type', 'Options', 'Option Identifiers',
        'Parent Sub Form', 'Required', 'Read Only', 'Long Text', 'Multi Choice',
        'Timestamp', 'Geostamp', 'Hint', 'Visibility expression', 'Validity expression',
        'Calculated expression','Derived type', 'Initial value']

to_change = list(final_df.columns)
cols_to_add = list(set(origin) - set(to_change))

if len(cols_to_add) == 0:
    final_df = final_df[origin]
else:
    for x in cols_to_add:
        final_df[x] = np.nan
    final_df = final_df[origin]
    
final_df.head(5)
# Out:
#                                       Question title        Identifier  \
# 0                                      Enumerator ID     enumerator_id
# 1  My name is [Enumerator name] and I work for th...      consent_text
# 2               Do you consent to being interviewed?           consent
# 3                                               Date              date
# 4                                          Form name  name_of_the_form
#
#       Type    Options Option Identifiers Parent Sub Form Required Read Only  \
# 0     text        NaN                NaN             NaN   always       NaN
# 1     text        NaN                NaN             NaN      NaN    always
# 2  boolean        NaN                NaN             NaN   always       NaN
# 3     date        NaN                NaN             NaN   always       NaN
# 4   select  Form name          Form name             NaN   always       NaN
#
#   Long Text Multi Choice  Timestamp  Geostamp Hint Visibility expression  \
# 0       NaN          NaN        NaN       NaN  NaN                   NaN
# 1       NaN          NaN        NaN       NaN  NaN                   NaN
# 2       NaN          NaN        NaN       NaN  NaN                   NaN
# 3       NaN          NaN        NaN       NaN  NaN                   NaN
# 4       NaN          NaN        NaN       NaN  NaN                   NaN
#
#   Validity expression  Calculated expression  Derived type  Initial value
# 0                 NaN                    NaN           NaN            NaN
# 1                 NaN                    NaN           NaN            NaN
# 2                 NaN                    NaN           NaN            NaN
# 3                 NaN                    NaN           NaN            NaN
# 4                 NaN                    NaN           NaN            NaN

# %%
# adjust bools and always options:
always = ["Required", "Read Only"]
bools = ["Long Text", "Multi Choice", "Timestamp", "Geostamp"]

for x in always:
    try:
        final_df[x].replace("always", "Yes",
                      regex = True,
                      inplace = True)
    except Exception:
        pass
    
for y in bools:
    try:
        final_df[y].replace(True, "Yes",
                      regex = True,
                      inplace = True)
    except Exception:
        pass
    
final_df.tail(5)
# Out:
#                                        Question title  \
# 15                                Feedback mechanisms
# 0   If you have any suggestions or complaints abou...
# 1   If yes, how do you do this? (Do not read the o...
# 2                                   If Other, specify
# 16  Do you have any additional feedback for the ICRC?
#
#                        Identifier     Type  \
# 15            feedback_mechanisms    group
# 0                   icrc_feedback  boolean
# 1         icrc_feedback_mechanism   select
# 2   icrc_feedback_mechanism_other     text
# 16             additional_comment     text
#
#                                               Options  \
# 15                                                NaN
# 0                                                 NaN
# 1   Speak to a volunteer, Write a letter, Go to th...
# 2                                                 NaN
# 16                                                NaN
#
#                                    Option Identifiers      Parent Sub Form  \
# 15                                                NaN                  NaN
# 0                                                 NaN  Feedback mechanisms
# 1   Speak to a volunteer, Write a letter, Go to th...  Feedback mechanisms
# 2                                                 NaN  Feedback mechanisms
# 16                                                NaN                  NaN
#
#    Required Read Only Long Text Multi Choice  Timestamp  Geostamp Hint  \
# 15      NaN       NaN       NaN          NaN        NaN       NaN  NaN
# 0       Yes       NaN       NaN          NaN        NaN       NaN  NaN
# 1       Yes       NaN       NaN          Yes        NaN       NaN  NaN
# 2       Yes       NaN       NaN          NaN        NaN       NaN  NaN
# 16      NaN       NaN       Yes          NaN        NaN       NaN  NaN
#
#                         Visibility expression Validity expression  \
# 15                                        NaN                 NaN
# 0                                         NaN                 NaN
# 1                        icrc_feedback = true                 NaN
# 2   CONTAINS(icrc_feedback_mechanism,"Other")                 NaN
# 16                                        NaN                 NaN
#
#     Calculated expression  Derived type  Initial value
# 15                    NaN           NaN            NaN
# 0                     NaN           NaN            NaN
# 1                     NaN           NaN            NaN
# 2                     NaN           NaN            NaN
# 16                    NaN           NaN            NaN

# %%
# final cleaning:
question_type_map = {
    'group':'Sub Form', 'select':'Select', 'signature':'Signature', 'image':'Image', 'time':'Time',
    'text':'Free Text', 'datetime':'Date+Time', 'email':'Email', 'barcode':'Barcode', 'decimal':'Decimal',
    'sketch':'Sketch', 'integer':'Integer', 'boolean':'Yes/No', 'calculated':'Calculated',
    'password':'Password', 'date':'Date', 'location':'Location', 'phone_number':'Phone No.' 
}

def final_adj():
    df = final_df
    df.fillna("",
              inplace = True)
    df["Type"].replace(question_type_map,
                       inplace = True)
    df["Options"] = (df["Options"]
                    .str.replace(", ", ","))
    df["Option Identifiers"] = (df["Option Identifiers"]
                               .str.replace(", ", ","))
    return df

final_adj().tail(5)
# Out:
#                                        Question title  \
# 15                                Feedback mechanisms
# 0   If you have any suggestions or complaints abou...
# 1   If yes, how do you do this? (Do not read the o...
# 2                                   If Other, specify
# 16  Do you have any additional feedback for the ICRC?
#
#                        Identifier       Type  \
# 15            feedback_mechanisms   Sub Form
# 0                   icrc_feedback     Yes/No
# 1         icrc_feedback_mechanism     Select
# 2   icrc_feedback_mechanism_other  Free Text
# 16             additional_comment  Free Text
#
#                                               Options  \
# 15
# 0
# 1   Speak to a volunteer,Write a letter,Go to the ...
# 2
# 16
#
#                                    Option Identifiers      Parent Sub Form  \
# 15
# 0                                                      Feedback mechanisms
# 1   Speak to a volunteer,Write a letter,Go to the ...  Feedback mechanisms
# 2                                                      Feedback mechanisms
# 16
#
#    Required Read Only Long Text Multi Choice Timestamp Geostamp Hint  \
# 15
# 0       Yes
# 1       Yes                              Yes
# 2       Yes
# 16                          Yes
#
#                         Visibility expression Validity expression  \
# 15
# 0
# 1                        icrc_feedback = true
# 2   CONTAINS(icrc_feedback_mechanism,"Other")
# 16
#
#    Calculated expression Derived type Initial value
# 15
# 0
# 1
# 2
# 16

# %%
# save prepared file:
def save_file():
    dff = final_adj()
    dff["Visibility expression"] = (dff["Visibility expression"]
                                    .str.replace('"',
                                    '\\"'))
    dff.to_csv(str(open_json()["title"]) + ".csv", index = False)
    
# calling final function:
save_file()

# %%
# end
